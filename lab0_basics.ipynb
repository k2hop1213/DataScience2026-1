# %% [markdown]
# # Lab0 : Introduction to Python Basics
# ## Objects, Variables, and more,,,,
# We will learn
# * Objects
# * Variables
# * and more...
# * and some math equations $$X = \frac{10}{x + 10}$$

# %%
print("Welcome to wonderful world of Python")
print("I love Python")
# Out:
# Welcome to wonderful world of Python
# I love Python

# %% [markdown]
# # Python에서는 모든것이 Object!!!!
# * object는 값이 있어야 함
# * object는 타입이 있다!!
# * python에서의 변수는 이름표!! (그 이상 그 이하도 아님.)(= 변수는 type이 없다. type을 갖는 것은 object)
# * 접근할 수 없는 object는 쓰래기 (자동으로 없어짐)

# %%
print("Hello World")
print(3.4)
print(10)
# Out:
# Hello World
# 3.4
# 10

# %%
print(type("Hello World"))
print(type(3.4))
print(type(10))
print(type(print))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'builtin_function_or_method'>

# %%
welcome_msg = "Hello World"
print(welcome_msg)
# Out:
# Hello World

# %% [markdown]
# - b 가 a를 가리키는게 아니라 3을 가리키게됨

# %%
a = 3
b = 4

print(id(a))
print(id(b))

b = a

print(b)
print(id(b))
# Out:
# 140734782526648
# 140734782526680
# 3
# 140734782526648

# %% [markdown]
# ## 변수이름
# - 알파벳 숫자 언더바 활용
# - 대소문자 구문됨
# - 숫자로 시작하면 안됨

# %% [markdown]
# ## Expressions
# - 계산을 해서 값을 내야 하는것

# %% [markdown]
# ## type conversion
# - type conversion을 하면 새로운 object가 생김

# %%
print(int(-2.3))
str(93)
# Out:
# -2
# '93'

# %% [markdown]
# ## 연산 순서
# 1. 괄호
# 2. **(거듭제곱)
# 3. +,- (부호바꾸기)
# 4. *,/,//,% (// : 정수 나눗셈 (몫만))
# 5. +,- (더하기 빼기)

# %%
8 - 3 * 2 - (1 + 1)
# Out:
# 0

# %%
a = 'hello'
b = 'world'
a+" "+b
(a + " ")*3
# Out:
# 'hello hello hello '
